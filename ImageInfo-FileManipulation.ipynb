# %%
import os
from google.colab import drive
from PIL import Image
import shutil
import random

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
4/1AY0e-g77VE5PLz8u9IdptGbcMKt63sGlhA-u-Ayu5xTd5rdSdDB0WHxLI-w

# %%
os.chdir( '/content/drive/MyDrive/' )

# %%
os.listdir()
# Out:
# ['Colab Notebooks', 'labeled', 'Train', 'Validation', 'Preprocessed']

# %%
#os.chdir( '/content/drive/MyDrive/Pictures/Polad' )
#os.listdir()
#folders_tina = [ 'upleash', 'kamera telefon' ] vo eden folder se
#folders_ivica = [ 'Daylight sky', 'Sky at night' ]

# %%
# os.chdir( '/content/drive/MyDrive/Pictures' )
# images = []

# for x in os.listdir() :
#     os.chdir( f'/content/drive/MyDrive/Pictures/{x}' )
#     print( x+":", len( os.listdir() ) )

# %%
# os.chdir( '/content/drive/MyDrive/Temni sliki' )
# print( os.getcwd() ) 
# COUNT = 1
  
# def increment(): 
#     global COUNT 
#     COUNT = COUNT + 1

# for f in os.listdir(): 
#     f_name, f_ext = os.path.splitext( f ) 
#     f_name = str( COUNT ) 
#     increment() 
  
#     new_name = 'Dark_{}{}'.format( f_name, f_ext.lower() ) 
#     os.rename( f, new_name )

# %%
# for x in file_full :
#     asd = x.split( "." )
#     if asd[ 1 ] != "jpg" :
#         print( x )
#         img = Image.open(x)
#         target_name = asd[ 0 ] + ".jpg"
#         rgb_image = img.convert('RGB')
#         rgb_image.save(target_name)
#         print("Converted image saved as " + target_name)

# %%
# for x in file_full :
#     asd = x.split( "." )
#     if asd[ 1 ] != "jpg" :
#         print( "Removed :" + x )
#         os.remove( x )

# %%
# #os.chdir( polad_path )
# file_full = os.listdir()
# et = []
# for x in file_full :
#     asd = x.split( "." )
#     et.append( asd[ 1 ] )

# %%
# set( et )

# %% [markdown]
# Transfer images from personal foders to main personal folder

# %%
# personal_path = '/content/drive/MyDrive/Personal-Images'
# places_path = '/content/drive/MyDrive/Places365-Images'
# dimitri_path = '/content/drive/MyDrive/Pictures/Dimitri'
# ivica_path = '/content/drive/MyDrive/Pictures/Ivica'
# jasmina_path = '/content/drive/MyDrive/Pictures/Jasmina'
# tina_path = '/content/drive/MyDrive/Pictures/Tina'
# polad_path = '/content/drive/MyDrive/Pictures/Polad'

# %%
# dest = shutil.move( dimitri_path, personal_path )

# %%
# for x in '/content/drive/MyDrive/Personal-Images/Dimitri/' :
#     shutil.move( x, personal_path )

# %%
# os.chdir( polad_path )
# for x in os.listdir() :
#     shutil.move( x, personal_path )

# %%
# os.chdir( personal_path )
# dir = os.listdir()

# initial = []

# for x in dir :
#     asd = x.split( "." )
#     initial.append( asd[ 0 ][ 0 ] )
#     initial_set = list( set( initial ) )


# for y in initial_set :
#     count = 0
#     for z in initial :
#         if z == y:
#             count += len( z )
#     #print( count )
#     print( f"{y}: { count } " )

# print( "Total : " + str( len( dir ) ) )

# %%
# print( initial )

# %%
# for x in file_full :
#     asd = x.split( "." )
#     if asd[ 1 ] != "jpg" :
#         print( "Removed :" + x )
#         os.remove( x )

# %%
# folders_ivica = [ 'Daylight sky', 'Sky at night' ]

# %%
# os.chdir( ivica_path )
# for x in os.listdir() :
#     shutil.move( x, personal_path )

# %%
# os.chdir( '/content/drive/MyDrive/Pictures/Places365-Images' )
# for x in os.listdir() :
#     shutil.move( x, places_path )

# %% [markdown]
# Спојување

# %%
# os.chdir( '/content/drive/MyDrive/' )
# images = []

# for x in os.listdir() :
#     os.chdir( f'/content/drive/MyDrive/{x}' )
#     print( x+":", len( os.listdir() ) )

# %%
# os.chdir( '/content/drive/MyDrive/Ivica Labeled' )
# os.listdir()

# %%
# labeled = '/content/drive/MyDrive/labeled'
# d_labeled = '/content/drive/MyDrive/Dimitri labeled'

# %%
# os.chdir( d_labeled )
# os.listdir()

# %%
# os.chdir( d_labeled )
# for x in os.listdir() :
#     shutil.move( x, labeled )

# %%
# i_labeled = '/content/drive/MyDrive/Ivica Labeled/1'
# os.chdir( i_labeled )
# len( os.listdir() )

# %%
# labeled = '/content/drive/MyDrive/labeled/1'
# os.chdir( i_labeled )
# len( os.listdir() )

# %%
# os.chdir( i_labeled )
# for x in os.listdir() :
#     shutil.move( x, labeled )

# %%
# os.chdir( "/content/drive/MyDrive/Tina Labeled" )
# list_dir = os.listdir()

# for x in list_dir :
#     os.chdir( f'/content/drive/MyDrive/Tina Labeled/{x}' )
#     print( x, len( os.listdir() ) )

# %%
# folder_num = 4
# i_labeled = f"/content/drive/MyDrive/Tina Labeled/{folder_num}"
# labeled = f'/content/drive/MyDrive/labeled/{folder_num}'
# os.chdir( i_labeled )
# for x in os.listdir() :
#     shutil.move( x, labeled )

# %%
# total = 0
# os.chdir( '/content/drive/MyDrive/labeled' )
# list_dir = os.listdir()

# for x in list_dir :
#     os.chdir( f'/content/drive/MyDrive/labeled/{x}' )
#     how_many =  len( os.listdir() )
#     total += how_many
#     print( x, how_many )
# print( f"Total: {total}" )

# %%
# os.chdir( "/content/drive/MyDrive/Temni sliki" )
# list_dir = os.listdir()
# len( list_dir )

# %%
# os.chdir( "/content/drive/MyDrive/3ka dimitri" )
# list_dir = os.listdir()
# len( list_dir )

# %%
# to_3ka = "/content/drive/MyDrive/labeled/3"

# %%
# os.chdir( "/content/drive/MyDrive/Temni sliki" )
# for x in os.listdir() :
#     shutil.move( x, "/content/drive/MyDrive/labeled/3" )

# %%
# os.chdir( "/content/drive/MyDrive/Temni sliki" )
# len( os.listdir() )

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_val, y_train, y_val = train_test_split( X, y, test_size = 0.15, random_state = 1 )

# %% [markdown]
# Split Train - Validation

# %%
# def split_test_valid_test( split_ratio, set_path, random_seed ) :

#     random.seed( random_seed )
    
#     total = 0

#     test_x = []
#     valid_x = []
#     test_labels = []
#     valid_labels = []

#     os.chdir( set_path )
#     list_dir = os.listdir()

#     for x in list_dir :
#         os.chdir( f'/content/drive/MyDrive/labeled/{x}' )
#         how_many =  len( os.listdir() )
#         total += how_many

#         test_set = int( round( how_many * ( 1 - split_ratio ), 0 ) )
#         valid_set = int( round( how_many * split_ratio, 0 ) )


#         print( f"Set: { x } - { how_many } items" )
#         print( f"Test: { test_set }" )
#         print( f"Validation: { valid_set }" )
#         print( f"Total: { test_set + valid_set }" )
#         print( "---------" ) 

#     test_set = int( round( total * ( 1 - split_ratio ), 0 ) )
#     valid_set = int( round( total * split_ratio, 0 ) )
    
#     print( "---------" ) 
#     print( f"United set: { total } items" )
#     print( f"Test: { test_set }" )
#     print( f"Validation: { valid_set }" )
#     print( f"Total: { test_set + valid_set }" )
#     print( "---------" )

# %%
# set_path = "/content/drive/MyDrive/labeled"
# split_ratio = 0.2

# split_test_valid( split_ratio, set_path )

# %%
# test_x, validation_x, test_y, validation_y =

# %%
# set_path = "/content/drive/MyDrive/labeled/Day"
# os.chdir( set_path )
# for ind, x in enumerate( os.listdir() ):
#     print( ind + 1, x )

# %%
# import random

# random.seed(10)
# nums = [ x for x in range( 1, 3308 ) ]
  
# random_nums = random.sample( nums, 662 )

# test_x = []
# valid_x = []
# test_labels = []
# valid_labels = []
# set_path = "/content/drive/MyDrive/labeled/Day"
# os.chdir( set_path )
# for ind, x in enumerate( os.listdir() ):
#     #print( ind + 1, x )
#     if ind in random_nums :
#         valid_x.append( x )
#         valid_labels.append( "Day" )
#     if ind not in random_nums :
#         test_x.append( x )
#         test_labels.append( "Day" )


# print( f"Test_x set: { len( test_x ) }" )
# print( f"Validation_x set: { len( valid_x ) }" )
# print( f"Test_labels set: { len( test_labels ) }" )
# print( f"Validation_labels set: { len( valid_labels ) }" )

# return test_x, valid_x, test_labels, valid_labels

# %%
def split_test_valid( split_ratio, set_path, random_seed = 1, print_ratio = False, include_path = True ) :

    """
    This functions lists through a directory containing different sets in sorted subdirectories and returns test_x, valid_x, test_labels, valid_labels ( or x and y ) for further use.
    The arguments that need to be provided:
        split_ratio: is the ratio for the data set to be split along. Acceptable input is a float between 0 and 1 i.e. the percentage needed for further use; 
        set_path: is the path to the main directory where the subdirectories are located.
    Optional arguments:
         random_seed: is self-explanatory;
         print_ratio: prints the int ratio of the split.
         include_path: whether or not to include the full path in the train and test sets.
            If True returns: '/content/drive/MyDrive/Directory/Subdirectiory/Image.jpg';
            If False returns: 'Image.jpg'.

    *DK
    """

    random.seed( random_seed )
    
    total = 0

    test_x = []
    valid_x = []
    test_labels = []
    valid_labels = []

    if set_path[ -1 ] == "/" :
        set_path = set_path[0:-1]

    os.chdir( set_path )
    list_dir = os.listdir()

    for folder in list_dir :
        os.chdir( f'{ set_path}/{ folder }' )
        how_many =  len( os.listdir() )
        total += how_many

        test_set = int( round( how_many * ( 1 - split_ratio ), 0 ) )
        valid_set = int( round( how_many * split_ratio, 0 ) )

        nums = [ x for x in range( 1, how_many ) ]
        random_nums = random.sample( nums, valid_set )

        # The split itself :
        for ind, item in enumerate( os.listdir() ):

            if ind in random_nums :
                if include_path == True :
                    valid_x.append( f"{set_path}/{folder}/{item}" )
                elif include_path == False :
                    valid_x.append( item )

                valid_labels.append( folder )

            if ind not in random_nums :

                if include_path == True :
                    test_x.append( f"{set_path}/{folder}/{item}" )
                elif include_path == False :
                    test_x.append( item )

                test_labels.append( folder )

        if print_ratio == True :

            print( f"Set: { folder } - { how_many } items" )
            print( f"Test: { test_set }" )
            print( f"Validation: { valid_set }" )
            print( f"Total: { test_set + valid_set }" )
            print( "---------" )
        elif print_ratio == False :
            pass
    
    if print_ratio == True :
        test_set = int( round( total * ( 1 - split_ratio ), 0 ) )
        valid_set = int( round( total * split_ratio, 0 ) )

        print( "---------" ) 
        print( f"United set: { total } items" )
        print( f"Test: { test_set }" )
        print( f"Validation: { valid_set }" )
        print( f"Total: { test_set + valid_set }" )
        print( "---------" )
    elif print_ratio == False :
            pass

    return test_x, valid_x, test_labels, valid_labels

# %%
def check_label_split( dataset ) :

    """
    Companion to the split_test_valid() function.
    To be used only on Labels.

    *DK
    """
    total = 0
    check = set( dataset )
    print( "Categories:" )
    for item in check :
        items = dataset.count( item )
        print( item, items )
        total += items
    print( "---" )
    print( f"Total items: { total }" )

# %%
set_path = "/content/drive/MyDrive/labeled"
split_ratio = 0.15

train_x, validation_x, train_labels, validation_labels  = split_test_valid( split_ratio, set_path, random_seed = 42, print_ratio = False, include_path = True )

# %%
check_label_split( validation_labels )
# Out:
# Categories:
# Day 496
# No_Sky 574
# Night-Not_Separated 132
# Night-Separated 94
# ---
# Total items: 1296

# %%
check_label_split( train_labels )
# Out:
# Categories:
# Day 2812
# No_Sky 3252
# Night-Not_Separated 747
# Night-Separated 533
# ---
# Total items: 7344

# %%
print( f"Test_x :{len( train_x)}" )
print( f"Validation_x: {len( validation_x )}" )
# Out:
# Test_x :7344
# Validation_x: 1296

# %%
import cv2
from keras.applications.xception import preprocess_input as X_pre
from keras.applications.resnet50 import preprocess_input as Res_pre
import numpy as np

def load_image( path ) :
  # READ AND PREPROCESS IMAGE HERE
  #cv2.imread
  image = cv2.imread( path ).astype( np.float32 )
  image_resized = X_pre( cv2.resize( image, dsize = ( 224, 224 ) ) )
  return image_resized

def load_dataset( files ) :
  vector = []
  for file in files:
    vector.append( load_image( file ) )
  return np.array( vector )


X_train = load_dataset( train_x )
X_val = load_dataset( validation_x )

# %%
type( X_train )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-eb445f4533bf> in <module>()
# ----> 1 type( X_train )
#
# NameError: name 'X_train' is not defined

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20,20))

for i in range( 5 * 4 ) :
    # dodavanje na podgrafik
    ax1 = fig.add_subplot( 5, 4, ( i + 1 ) )
    # crtanje na podgrafikot
    ax1.imshow( X_train[ i ] )
    #  dodavanje na tekst na podgrafikot
    title = "Class: " + train_labels[ i ]
    plt.title( title )

# snimanje na grafikot
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20,20))

for i in range( 5 * 4 ) :
    # dodavanje na podgrafik
    ax1 = fig.add_subplot( 5, 4, ( i + 1 ) )
    # crtanje na podgrafikot
    ax1.imshow( X_val[ i ] )
    #  dodavanje na tekst na podgrafikot
    title = "Class: " + validation_labels[ i ]
    plt.title( title )

# snimanje na grafikot
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
#!pip install compress-pickle

# %%
import gzip
import pickle
import bz2
import _pickle as cPickle

# %%
# tuka imame problem bidejki pickle ne sobira poveke od 4 GB

def compressed_pickle( path, title, data ) :
    with bz2.BZ2File( path + "/" + title + ".pbz2", "w" ) as f :
        cPickle.dump( data, f )

# %%
processed_path = "/content/drive/MyDrive/Preprocessed"
file_name = "TrainX_Preprocessed_Xception_224x224_pickle_compressed"

compressed_pickle( processed_path, file_name, X_train )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f7730830f05c> in <module>()
#       2 file_name = "TrainX_Preprocessed_Xception_224x224_pickle_compressed"
#       3
# ----> 4 compressed_pickle( processed_path, file_name, X_train )
#
# NameError: name 'X_train' is not defined

# %%
import pickle

var_to_pickle = X_val

pickle_out = open( "/content/drive/MyDrive/Preprocessed/Xception-Val_x-244x244.pickle", "wb" )
pickle.dump( var_to_pickle, pickle_out )
pickle_out.close()

# %% [markdown]
# Model

# %%
from sklearn.datasets import load_files  
import numpy as np
from keras.utils import np_utils
import cv2

import keras
from keras.preprocessing.image import load_img, img_to_array
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.applications.xception import Xception
from keras.applications.densenet import DenseNet169
from keras.applications.resnet import ResNet50
from keras.models import Model, Sequential, load_model
from keras.layers import Dense, Activation, Conv2D, Flatten, MaxPooling2D, AveragePooling2D, Dropout, GlobalAveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ModelCheckpoint

import matplotlib.pyplot as plt

plt.style.use( "ggplot" )

# %%
#del model_Xception


model_Xception = Xception( include_top = False, input_shape=( 224, 224, 3 ), weights = 'imagenet' )
for layer in model_Xception.layers[ : -5 ] :
  layer.trainable = False
flatten = Flatten()( model_Xception.output )
custom_layer = Dense( 1000, activation = 'relu' )( flatten )
output = Dense( 133, activation = 'softmax' )( custom_layer )

model_Xception = Model( inputs = model_Xception.inputs, outputs = output)

# %%
model_Xception.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 111, 111, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 111, 111, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# ...

# %%
optimzer = keras.optimizers.Adam( lr = 0.00001 )
model_Xception.compile( loss = 'categorical_crossentropy', optimizer = optimzer, metrics = [ 'accuracy' ] )

# %%
test_x, validation_x, test_y, validation_y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-531458bac16e> in <module>()
# ----> 1 test_x, validation_x, test_y, validation_y
#
# NameError: name 'test_x' is not defined

# %%
# checkpoint = ModelCheckpoint(     
#                                 'best_model.pt', monitor = 'val_accuracy',
#                                 verbose = 1, save_best_only = True, mode = 'max'
#                                )

model_Xception.fit(
                    np.array(X_train ),
                    np.array(test_y),
                    validation_data = ( data, np.array(validation_y) ),
                    epochs = 25,
                    #callbacks = [ checkpoint ], 
                    batch_size = 40
                        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6c22b4bbea30> in <module>()
#       4 #                                )
#       5
# ----> 6 model_Xception.fit(
#       7                     np.array(X_train ),
#       8                     np.array(test_y),
#
# NameError: name 'model_Xception' is not defined

# %%
np.array(validation_y)
# Out:
# array(['Day', 'Day', 'Day', ..., 'No_Sky', 'No_Sky', 'No_Sky'],
#       dtype='<U19')
