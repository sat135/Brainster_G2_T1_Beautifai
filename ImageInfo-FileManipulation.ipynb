# %%
import os
from google.colab import drive
from PIL import Image

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
4/1AY0e-g7FjUJhN9PY3UixYGQEDMKBVBSvG65v5Vjgr-OmBFf5R5l8gjUG6To

# %%
os.chdir( '/content/drive/MyDrive/Pictures' )

# %%
os.listdir()
# Out:
# ['Tina', 'Places365-Images', 'Dimitri', 'Ivica', 'Polad']

# %%
#os.chdir( '/content/drive/MyDrive/Pictures/Polad' )
#os.listdir()
folders_tina = [ 'upleash', 'kamera telefon' ]
folders_ivica = [ 'Daylight sky', 'Sky at night' ]

# %%
os.chdir( '/content/drive/MyDrive/Pictures' )
images = []

for x in os.listdir() :
    os.chdir( f'/content/drive/MyDrive/Pictures/{x}' )
    print( len( os.listdir() ) )
# Out:
# 376
# 1
# 1241
# 2
# 96

# %%
os.chdir( '/content/drive/MyDrive/Pictures/Tina/upleash' )
print( len( os.listdir() ) )
# Out:
# 292

# %%
os.chdir( '/content/drive/MyDrive/Pictures/Tina/kamera telefon' )
print( len( os.listdir() ) )
# Out:
# 49

# %%
os.chdir( '/content/drive/MyDrive/Pictures/Ivica/Daylight sky' )
print( len( os.listdir() ) )
# Out:
# 100

# %%
os.chdir( '/content/drive/MyDrive/Pictures/Ivica/Sky at night' )
print( len( os.listdir() ) )
# Out:
# 64

# %%
374 + 292 + 49 + 4575 + 959 + 164 + 96
# Out:
# 6792

# %%
374 + 49 + 292
# Out:
# 715

# %%
os.chdir( '/content/drive/MyDrive/Pictures/Dimitri' )
print( len( os.listdir() ) )
# Out:
# 1241

# %%
os.chdir( '/content/drive/MyDrive/Pictures/Dimitri' )
print( os.getcwd() ) 
COUNT = 1
  
def increment(): 
    global COUNT 
    COUNT = COUNT + 1

for f in os.listdir(): 
    f_name, f_ext = os.path.splitext( f ) 
    f_name = str( COUNT ) 
    increment() 
  
    new_name = 'd{}{}'.format( f_name, f_ext.lower() ) 
    os.rename( f, new_name )
# Out:
# /content/drive/MyDrive/Pictures/Dimitri

# %%
len( os.listdir() )
# Out:
# 1241

# %%
file_full = os.listdir()

# %%
for x in file_full :
    asd = x.split( "." )
    if asd[ 1 ] != "jpg" :
        print( x )
        img = Image.open(x)
        target_name = asd[ 0 ] + ".jpg"
        rgb_image = img.convert('RGB')
        rgb_image.save(target_name)
        print("Converted image saved as " + target_name)
# Out:
# 304.png
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-147-58143dac87d5> in <module>()
#       3     if asd[ 1 ] != "jpg" :
#       4         print( x )
# ----> 5         img = Image.open(x)
#       6         target_name = asd[ 0 ] + ".jpg"
#       7         rgb_image = img.convert('RGB')
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: '304.png'

# %%
for x in file_full :
    asd = x.split( "." )
    if asd[ 1 ] != "jpg" :
        print( "Removed :" + x )
        os.remove( x )
# Out:
# Removed :304.png
# Removed :338.jpeg
# Removed :1118.jpeg
# Removed :1119.jpeg
# Removed :1120.jpeg

# %%
et = []
for x in file_full :
    asd = x.split( "." )
    et.append( asd[ 1 ] )

# %%
set( et )
# Out:
# {'jpg'}
