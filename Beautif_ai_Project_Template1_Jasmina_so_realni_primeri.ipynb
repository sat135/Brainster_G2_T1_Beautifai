# %% [markdown]
# # Beautif.ai classification
#
# The goal of your project is to create a robust classifier, to collect data and prepare custom dataset.
# You will build a model that will recognize 4 types of natural events in nature/indoor/outdoor:
#
# * Daylight sky
#   * <img src = "https://ak.picdn.net/shutterstock/videos/7077064/thumb/1.jpg" width = "50%" height="50%">
# * Sky at night
#   * <img src="https://i.pinimg.com/originals/ec/98/dd/ec98dd97904e60661b1d545a88006e6a.jpg" width="50%" height="50%"/>
#
# * Picture doesn't contain sky (no matter it's day or night)
#   * <img src= "https://www.hotelsolun.com/application/files/5515/6285/1004/1X9A8812.jpg" width="50%" height="50%"/>
#
#
# This project consists of the following activities :
#
#
# 1. Phase 1 : Dataset
#     * Team Planning
#     * Full git project Integration
#     * General Project Research
#     * Dataset Collection
#     * Dataset Preparation
# 2. Phase 2 : Training
#     * Research about neural networks
#     * Compose neural network architectures
#     * Ping Pong phase with Dataset labelers
#     * Generate syntethic data if needed
#     * Fine tunning of your model
# 3. Phase 3 : Deployment
#     * Analysis and benchmark Precision/Recall
#     * Model Deploy (Git)
#     * Write git Readme.md file
#     * Receive Feedback from PM

# %% [markdown]
# # Load Data

# %%
import os
from google.colab import drive
from PIL import Image
import shutil
import random
import cv2
from keras.applications.xception import preprocess_input as X_pre
from keras.applications.resnet50 import preprocess_input as Res_pre
import numpy as np

from sklearn.datasets import load_files  
import numpy as np
from keras.utils import np_utils
import cv2

import keras
from keras.preprocessing.image import load_img, img_to_array
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.applications.xception import Xception
from keras.applications.densenet import DenseNet169
from keras.applications.resnet import ResNet50
from keras.models import Model, Sequential, load_model
from keras.layers import Dense, Activation, Conv2D, Flatten, MaxPooling2D, AveragePooling2D, Dropout, GlobalAveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ModelCheckpoint

import matplotlib.pyplot as plt

plt.style.use( "ggplot" )

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def split_test_valid( split_ratio, set_path, random_seed = 1, print_ratio = False, include_path = True ) :

    """
    This functions lists through a directory containing different sets in sorted subdirectories and returns test_x, valid_x, test_labels, valid_labels ( or x and y ) for further use.
    The arguments that need to be provided:
        split_ratio: is the ratio for the data set to be split along. Acceptable input is a float between 0 and 1 i.e. the percentage needed for further use; 
        set_path: is the path to the main directory where the subdirectories are located.
    Optional arguments:
         random_seed: is self-explanatory;
         print_ratio: prints the int ratio of the split.
         include_path: whether or not to include the full path in the train and test sets.
            If True returns: '/content/drive/MyDrive/Directory/Subdirectiory/Image.jpg';
            If False returns: 'Image.jpg'.
    """

    random.seed( random_seed )
    
    total = 0

    test_x = []
    valid_x = []
    test_labels = []
    valid_labels = []

    default_location = os.getcwd()

    if set_path[ -1 ] == "/" :
        set_path = set_path[0:-1]

    os.chdir( set_path )
    list_dir = os.listdir( set_path )

    for folder in list_dir :
        os.chdir( f'{ set_path}/{ folder }' )
        how_many =  len( os.listdir() )
        total += how_many

        test_set = int( round( how_many * ( 1 - split_ratio ), 0 ) )
        valid_set = int( round( how_many * split_ratio, 0 ) )

        nums = [ x for x in range( 1, how_many ) ]
        random_nums = random.sample( nums, valid_set )

        # The split itself :
        for ind, item in enumerate( os.listdir() ):

            if ind in random_nums :
                if include_path == True :
                    valid_x.append( f"{set_path}/{folder}/{item}" )
                elif include_path == False :
                    valid_x.append( item )

                valid_labels.append( folder )

            if ind not in random_nums :

                if include_path == True :
                    test_x.append( f"{set_path}/{folder}/{item}" )
                elif include_path == False :
                    test_x.append( item )

                test_labels.append( folder )

        if print_ratio == True :

            print( f"Set: { folder } - { how_many } items" )
            print( f"Train: { test_set }" )
            print( f"Validation: { valid_set }" )
            print( f"Total: { test_set + valid_set }" )
            print( "---------" )
        elif print_ratio == False :
            pass

    os.chdir( default_location )
    
    if print_ratio == True :
        test_set = int( round( total * ( 1 - split_ratio ), 0 ) )
        valid_set = int( round( total * split_ratio, 0 ) )

        print( "---------" ) 
        print( f"United set: { total } items" )
        print( f"Train: { test_set }" )
        print( f"Validation: { valid_set }" )
        print( f"Total: { test_set + valid_set }" )
        print( "---------" )
    elif print_ratio == False :
            pass

    return test_x, valid_x, test_labels, valid_labels

# %%
set_path = "/content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224"
split_ratio = 0.15

train_x, validation_x, train_labels, validation_labels  = split_test_valid( split_ratio, set_path, random_seed = 42, print_ratio = True )
# Out:
# Set: Night-Separated - 658 items
# Train: 559
# Validation: 99
# Total: 658
# ---------
# Set: No_Sky - 3792 items
# Train: 3223
# Validation: 569
# Total: 3792
# ---------
# Set: Day - 3303 items
# Train: 2808
# Validation: 495
# Total: 3303
# ---------
# Set: Night-Not_Separated - 887 items
# Train: 754
# Validation: 133
# Total: 887
# ---------
# ---------
# United set: 8640 items
# Train: 7344
# Validation: 1296
# Total: 8640
# ---------

# %%
train_labels = np.array(train_labels)
validation_labels = np.array(validation_labels)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
le.fit(train_labels)
# Out:
# LabelEncoder()

# %%
train_targets = le.transform(train_labels)
val_targets = le.transform(validation_labels)

# %%
from tensorflow.keras.utils import to_categorical

# %%
train_targets = np_utils.to_categorical(train_targets,num_classes=4)
val_targets = np_utils.to_categorical(val_targets,num_classes=4)

# %% [markdown]
# # Visualize Data Distribution

# %% [markdown]
# # Image Preprocessing

# %%
def load_image( path ) :
  # READ AND PREPROCESS IMAGE HERE
  #cv2.imread
  image = cv2.imread( path ).astype( np.float32 )
  image_resized = Res_pre( image )
  return image_resized

def load_dataset( files ) :
  vector = []
  brojcanik = 0
  for file in files:
    brojcanik = brojcanik + 1
    vector.append( load_image( file ) )
    if brojcanik%100 == 0:
      print(f"procesirani se vkupno {brojcanik} sliki")
  return np.array( vector )


X_train = load_dataset( train_x )
X_val = load_dataset( validation_x )
# Out:
# procesirani se vkupno 100 sliki
# procesirani se vkupno 200 sliki
# procesirani se vkupno 300 sliki
# procesirani se vkupno 400 sliki
# procesirani se vkupno 500 sliki
# procesirani se vkupno 600 sliki
# procesirani se vkupno 700 sliki
# procesirani se vkupno 800 sliki
# procesirani se vkupno 900 sliki
# procesirani se vkupno 1000 sliki
# procesirani se vkupno 1100 sliki
# procesirani se vkupno 1200 sliki
# procesirani se vkupno 1300 sliki
# procesirani se vkupno 1400 sliki
# procesirani se vkupno 1500 sliki
# procesirani se vkupno 1600 sliki
# procesirani se vkupno 1700 sliki
# procesirani se vkupno 1800 sliki
# procesirani se vkupno 1900 sliki
# procesirani se vkupno 2000 sliki
# procesirani se vkupno 2100 sliki
# procesirani se vkupno 2200 sliki
# procesirani se vkupno 2300 sliki
# procesirani se vkupno 2400 sliki
# procesirani se vkupno 2500 sliki
# procesirani se vkupno 2600 sliki
# procesirani se vkupno 2700 sliki
# procesirani se vkupno 2800 sliki
# procesirani se vkupno 2900 sliki
# procesirani se vkupno 3000 sliki
# procesirani se vkupno 3100 sliki
# procesirani se vkupno 3200 sliki
# procesirani se vkupno 3300 sliki
# procesirani se vkupno 3400 sliki
# procesirani se vkupno 3500 sliki
# procesirani se vkupno 3600 sliki
# procesirani se vkupno 3700 sliki
# procesirani se vkupno 3800 sliki
# procesirani se vkupno 3900 sliki
# procesirani se vkupno 4000 sliki
# procesirani se vkupno 4100 sliki
# procesirani se vkupno 4200 sliki
# procesirani se vkupno 4300 sliki
# procesirani se vkupno 4400 sliki
# procesirani se vkupno 4500 sliki
# procesirani se vkupno 4600 sliki
# procesirani se vkupno 4700 sliki
# procesirani se vkupno 4800 sliki
# procesirani se vkupno 4900 sliki
# procesirani se vkupno 5000 sliki
# procesirani se vkupno 5100 sliki
# procesirani se vkupno 5200 sliki
# procesirani se vkupno 5300 sliki
# procesirani se vkupno 5400 sliki
# procesirani se vkupno 5500 sliki
# procesirani se vkupno 5600 sliki
# procesirani se vkupno 5700 sliki
# procesirani se vkupno 5800 sliki
# procesirani se vkupno 5900 sliki
# procesirani se vkupno 6000 sliki
# procesirani se vkupno 6100 sliki
# procesirani se vkupno 6200 sliki
# procesirani se vkupno 6300 sliki
# procesirani se vkupno 6400 sliki
# procesirani se vkupno 6500 sliki
# procesirani se vkupno 6600 sliki
# procesirani se vkupno 6700 sliki
# procesirani se vkupno 6800 sliki
# procesirani se vkupno 6900 sliki
# procesirani se vkupno 7000 sliki
# procesirani se vkupno 7100 sliki
# procesirani se vkupno 7200 sliki
# procesirani se vkupno 7300 sliki
# procesirani se vkupno 100 sliki
# procesirani se vkupno 200 sliki
# procesirani se vkupno 300 sliki
# procesirani se vkupno 400 sliki
# procesirani se vkupno 500 sliki
# procesirani se vkupno 600 sliki
# procesirani se vkupno 700 sliki
# procesirani se vkupno 800 sliki
# procesirani se vkupno 900 sliki
# procesirani se vkupno 1000 sliki
# procesirani se vkupno 1100 sliki
# procesirani se vkupno 1200 sliki

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20,20))

for i in range( 5 * 4 ) :
    # dodavanje na podgrafik
    ax1 = fig.add_subplot( 5, 4, ( i + 1 ) )
    # crtanje na podgrafikot
    ax1.imshow( X_train[ i ] )
    #  dodavanje na tekst na podgrafikot
    title = "Class: " + train_labels[ i ]
    plt.title( title )

# snimanje na grafikot
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20,20))

for i in range( 5 * 4 ) :
    # dodavanje na podgrafik
    ax1 = fig.add_subplot( 5, 4, ( i + 1 ) )
    # crtanje na podgrafikot
    ax1.imshow( X_val[ i ] )
    #  dodavanje na tekst na podgrafikot
    title = "Class: " + validation_labels[ i ]
    plt.title( title )

# snimanje na grafikot
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from keras.applications.resnet import ResNet101

# %% [markdown]
# # Define Model Architecture

# %%
model = ResNet50(include_top=False, input_shape = (224,224,3), weights='imagenet')
for layer in model.layers:
  layer.trainable=False
flat = Flatten()(model.output)
hidden = Dense(1024, activation='relu')(flat)
outputs = Dense(4, activation='softmax')(hidden)
model = Model(inputs = model.inputs, outputs = outputs)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 100352)       0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         102761472   flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4)            4100        dense[0][0]
# ==================================================================================================
# Total params: 126,353,284
# Trainable params: 102,765,572
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %% [markdown]
# # Define Loss Function, Optimizator

# %%
optimzer = keras.optimizers.Adam(lr = 0.000001)
model.compile( loss = 'categorical_crossentropy', optimizer = optimzer, metrics = [ 'accuracy' ] )

# %% [markdown]
# # Define Augmentator

# %%
checkpoint = ModelCheckpoint(     
                                'best_model_JLN.pt', monitor = 'val_accuracy',
                                verbose = 1, save_best_only = True, mode = 'max'
                               )

model.fit(
                    X_train,
                    train_targets,
                    validation_data = ( X_val, val_targets ),
                    epochs = 50,
                    callbacks = [ checkpoint ], 
                    batch_size = 10
                        )
# Out:
# Epoch 1/50
# 735/735 [==============================] - 57s 64ms/step - loss: 1.0426 - accuracy: 0.6540 - val_loss: 0.4978 - val_accuracy: 0.8210
#
# Epoch 00001: val_accuracy improved from -inf to 0.82099, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 2/50
# 735/735 [==============================] - 46s 63ms/step - loss: 0.1962 - accuracy: 0.9408 - val_loss: 0.4346 - val_accuracy: 0.8472
#
# Epoch 00002: val_accuracy improved from 0.82099 to 0.84722, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 3/50
# 735/735 [==============================] - 46s 63ms/step - loss: 0.0642 - accuracy: 0.9922 - val_loss: 0.4181 - val_accuracy: 0.8519
#
# Epoch 00003: val_accuracy improved from 0.84722 to 0.85185, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 4/50
# 735/735 [==============================] - 46s 63ms/step - loss: 0.0277 - accuracy: 0.9984 - val_loss: 0.3982 - val_accuracy: 0.8634
#
# Epoch 00004: val_accuracy improved from 0.85185 to 0.86343, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 5/50
# 735/735 [==============================] - 46s 63ms/step - loss: 0.0171 - accuracy: 0.9990 - val_loss: 0.3947 - val_accuracy: 0.8657
#
# Epoch 00005: val_accuracy improved from 0.86343 to 0.86574, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 6/50
# 735/735 [==============================] - 46s 63ms/step - loss: 0.0099 - accuracy: 0.9998 - val_loss: 0.3896 - val_accuracy: 0.8742
#
# Epoch 00006: val_accuracy improved from 0.86574 to 0.87423, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 7/50
# 735/735 [==============================] - 46s 63ms/step - loss: 0.0069 - accuracy: 0.9999 - val_loss: 0.3884 - val_accuracy: 0.8781
#
# Epoch 00007: val_accuracy improved from 0.87423 to 0.87809, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 8/50
# 735/735 [==============================] - 46s 62ms/step - loss: 0.0128 - accuracy: 0.9985 - val_loss: 0.3895 - val_accuracy: 0.8804
#
# Epoch 00008: val_accuracy improved from 0.87809 to 0.88040, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 9/50
# 735/735 [==============================] - 46s 63ms/step - loss: 0.0048 - accuracy: 0.9993 - val_loss: 0.3970 - val_accuracy: 0.8819
#
# Epoch 00009: val_accuracy improved from 0.88040 to 0.88194, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 10/50
# 735/735 [==============================] - 46s 62ms/step - loss: 0.0027 - accuracy: 0.9999 - val_loss: 0.3970 - val_accuracy: 0.8812
#
# Epoch 00010: val_accuracy did not improve from 0.88194
# Epoch 11/50
# 735/735 [==============================] - 46s 62ms/step - loss: 0.0070 - accuracy: 0.9989 - val_loss: 0.3984 - val_accuracy: 0.8827
#
# Epoch 00011: val_accuracy improved from 0.88194 to 0.88272, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 12/50
# 735/735 [==============================] - 46s 63ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.4071 - val_accuracy: 0.8873
#
# Epoch 00012: val_accuracy improved from 0.88272 to 0.88735, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 13/50
# 735/735 [==============================] - 46s 63ms/step - loss: 0.0042 - accuracy: 0.9996 - val_loss: 0.4112 - val_accuracy: 0.8819
#
# Epoch 00013: val_accuracy did not improve from 0.88735
# Epoch 14/50
# 735/735 [==============================] - 46s 62ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.4245 - val_accuracy: 0.8812
#
# Epoch 00014: val_accuracy did not improve from 0.88735
# Epoch 15/50
# 735/735 [==============================] - 46s 62ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.4261 - val_accuracy: 0.8858
#
# Epoch 00015: val_accuracy did not improve from 0.88735
# Epoch 16/50
# 735/735 [==============================] - 46s 62ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.4173 - val_accuracy: 0.8873
#
# Epoch 00016: val_accuracy did not improve from 0.88735
# Epoch 17/50
# 735/735 [==============================] - 46s 62ms/step - loss: 3.1447e-04 - accuracy: 1.0000 - val_loss: 0.4278 - val_accuracy: 0.8881
#
# Epoch 00017: val_accuracy improved from 0.88735 to 0.88812, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 18/50
# 735/735 [==============================] - 46s 63ms/step - loss: 4.6818e-04 - accuracy: 1.0000 - val_loss: 0.4301 - val_accuracy: 0.8881
#
# Epoch 00018: val_accuracy did not improve from 0.88812
# Epoch 19/50
# 735/735 [==============================] - 45s 62ms/step - loss: 1.9187e-04 - accuracy: 1.0000 - val_loss: 0.4463 - val_accuracy: 0.8881
#
# Epoch 00019: val_accuracy did not improve from 0.88812
# Epoch 20/50
# 735/735 [==============================] - 46s 63ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.4951 - val_accuracy: 0.8904
#
# Epoch 00020: val_accuracy improved from 0.88812 to 0.89043, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 21/50
# 735/735 [==============================] - 46s 63ms/step - loss: 0.0079 - accuracy: 0.9995 - val_loss: 0.4682 - val_accuracy: 0.8881
#
# Epoch 00021: val_accuracy did not improve from 0.89043
# Epoch 22/50
# 735/735 [==============================] - 45s 62ms/step - loss: 8.1547e-05 - accuracy: 1.0000 - val_loss: 0.4574 - val_accuracy: 0.8912
#
# Epoch 00022: val_accuracy improved from 0.89043 to 0.89120, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 23/50
# 735/735 [==============================] - 46s 63ms/step - loss: 8.8837e-05 - accuracy: 1.0000 - val_loss: 0.4666 - val_accuracy: 0.8920
#
# Epoch 00023: val_accuracy improved from 0.89120 to 0.89198, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 24/50
# 735/735 [==============================] - 46s 63ms/step - loss: 0.0035 - accuracy: 0.9998 - val_loss: 0.4638 - val_accuracy: 0.8951
#
# Epoch 00024: val_accuracy improved from 0.89198 to 0.89506, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 25/50
# 735/735 [==============================] - 46s 63ms/step - loss: 2.3164e-04 - accuracy: 1.0000 - val_loss: 0.4795 - val_accuracy: 0.8943
#
# Epoch 00025: val_accuracy did not improve from 0.89506
# Epoch 26/50
# 735/735 [==============================] - 46s 62ms/step - loss: 2.7760e-04 - accuracy: 1.0000 - val_loss: 0.4775 - val_accuracy: 0.8951
#
# Epoch 00026: val_accuracy did not improve from 0.89506
# Epoch 27/50
# 735/735 [==============================] - 46s 63ms/step - loss: 1.0254e-05 - accuracy: 1.0000 - val_loss: 0.4817 - val_accuracy: 0.8951
#
# Epoch 00027: val_accuracy did not improve from 0.89506
# Epoch 28/50
# 735/735 [==============================] - 46s 63ms/step - loss: 7.0759e-06 - accuracy: 1.0000 - val_loss: 0.4880 - val_accuracy: 0.8927
#
# Epoch 00028: val_accuracy did not improve from 0.89506
# Epoch 29/50
# 735/735 [==============================] - 46s 63ms/step - loss: 5.4005e-06 - accuracy: 1.0000 - val_loss: 0.4894 - val_accuracy: 0.8958
#
# Epoch 00029: val_accuracy improved from 0.89506 to 0.89583, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 30/50
# 735/735 [==============================] - 46s 63ms/step - loss: 4.0515e-06 - accuracy: 1.0000 - val_loss: 0.4987 - val_accuracy: 0.8935
#
# Epoch 00030: val_accuracy did not improve from 0.89583
# Epoch 31/50
# 735/735 [==============================] - 46s 62ms/step - loss: 3.0948e-06 - accuracy: 1.0000 - val_loss: 0.5026 - val_accuracy: 0.8966
#
# Epoch 00031: val_accuracy improved from 0.89583 to 0.89660, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 32/50
# 735/735 [==============================] - 46s 63ms/step - loss: 2.5608e-06 - accuracy: 1.0000 - val_loss: 0.5090 - val_accuracy: 0.8958
#
# Epoch 00032: val_accuracy did not improve from 0.89660
# Epoch 33/50
# 735/735 [==============================] - 46s 62ms/step - loss: 1.8291e-06 - accuracy: 1.0000 - val_loss: 0.5155 - val_accuracy: 0.8951
#
# Epoch 00033: val_accuracy did not improve from 0.89660
# Epoch 34/50
# 735/735 [==============================] - 46s 63ms/step - loss: 1.5710e-06 - accuracy: 1.0000 - val_loss: 0.5196 - val_accuracy: 0.8966
#
# Epoch 00034: val_accuracy did not improve from 0.89660
# Epoch 35/50
# 735/735 [==============================] - 46s 63ms/step - loss: 1.0927e-06 - accuracy: 1.0000 - val_loss: 0.5284 - val_accuracy: 0.8974
#
# Epoch 00035: val_accuracy improved from 0.89660 to 0.89738, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 36/50
# 735/735 [==============================] - 46s 63ms/step - loss: 1.1492e-05 - accuracy: 1.0000 - val_loss: 0.5371 - val_accuracy: 0.9005
#
# Epoch 00036: val_accuracy improved from 0.89738 to 0.90046, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 37/50
# 735/735 [==============================] - 46s 63ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.5451 - val_accuracy: 0.8958
#
# Epoch 00037: val_accuracy did not improve from 0.90046
# Epoch 38/50
# 735/735 [==============================] - 46s 62ms/step - loss: 6.5907e-07 - accuracy: 1.0000 - val_loss: 0.5442 - val_accuracy: 0.8989
#
# Epoch 00038: val_accuracy did not improve from 0.90046
# Epoch 39/50
# 735/735 [==============================] - 46s 63ms/step - loss: 5.5204e-07 - accuracy: 1.0000 - val_loss: 0.5462 - val_accuracy: 0.8966
#
# Epoch 00039: val_accuracy did not improve from 0.90046
# Epoch 40/50
# 735/735 [==============================] - 46s 62ms/step - loss: 3.9144e-07 - accuracy: 1.0000 - val_loss: 0.5510 - val_accuracy: 0.8966
#
# Epoch 00040: val_accuracy did not improve from 0.90046
# Epoch 41/50
# 735/735 [==============================] - 46s 62ms/step - loss: 4.1141e-07 - accuracy: 1.0000 - val_loss: 0.5560 - val_accuracy: 0.8974
#
# Epoch 00041: val_accuracy did not improve from 0.90046
# Epoch 42/50
# 735/735 [==============================] - 46s 62ms/step - loss: 7.6130e-04 - accuracy: 0.9997 - val_loss: 0.5621 - val_accuracy: 0.8966
#
# Epoch 00042: val_accuracy did not improve from 0.90046
# Epoch 43/50
# 735/735 [==============================] - 46s 62ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.5621 - val_accuracy: 0.8943
#
# Epoch 00043: val_accuracy did not improve from 0.90046
# Epoch 44/50
# 735/735 [==============================] - 46s 62ms/step - loss: 4.4813e-07 - accuracy: 1.0000 - val_loss: 0.5659 - val_accuracy: 0.8943
#
# Epoch 00044: val_accuracy did not improve from 0.90046
# Epoch 45/50
# 735/735 [==============================] - 46s 62ms/step - loss: 3.6293e-07 - accuracy: 1.0000 - val_loss: 0.5676 - val_accuracy: 0.8951
#
# Epoch 00045: val_accuracy did not improve from 0.90046
# Epoch 46/50
# 735/735 [==============================] - 45s 62ms/step - loss: 3.1179e-07 - accuracy: 1.0000 - val_loss: 0.5752 - val_accuracy: 0.8935
#
# Epoch 00046: val_accuracy did not improve from 0.90046
# Epoch 47/50
# 735/735 [==============================] - 46s 62ms/step - loss: 2.1260e-06 - accuracy: 1.0000 - val_loss: 0.5725 - val_accuracy: 0.8958
#
# Epoch 00047: val_accuracy did not improve from 0.90046
# Epoch 48/50
# 735/735 [==============================] - 46s 62ms/step - loss: 6.5488e-04 - accuracy: 0.9999 - val_loss: 0.5796 - val_accuracy: 0.8966
#
# Epoch 00048: val_accuracy did not improve from 0.90046
# Epoch 49/50
# 735/735 [==============================] - 46s 62ms/step - loss: 7.0951e-05 - accuracy: 1.0000 - val_loss: 0.6169 - val_accuracy: 0.8981
#
# Epoch 00049: val_accuracy did not improve from 0.90046
# Epoch 50/50
# 735/735 [==============================] - 46s 62ms/step - loss: 0.0076 - accuracy: 0.9988 - val_loss: 0.5993 - val_accuracy: 0.8974
#
# Epoch 00050: val_accuracy did not improve from 0.90046

# %%
from sklearn.metrics import classification_report

Y_pred = model.predict(X_val)

real_prediction = np.argmax(Y_pred, axis=1)
real_targets = np.argmax(val_targets, axis=1)

target_names = ['Day', 'Night-Not_Separated', 'Night-Separated', 'No_Sky']
# print(classification_report(Y_test, Y_pred, target_names=target_names))
print(classification_report(real_targets, real_prediction, target_names=target_names))
# Out:
#                      precision    recall  f1-score   support
#
#                 Day       0.90      0.94      0.92       495
# Night-Not_Separated       0.82      0.79      0.80       133
#     Night-Separated       0.76      0.66      0.70        99
#              No_Sky       0.93      0.92      0.93       569
#
#            accuracy                           0.90      1296
#           macro avg       0.85      0.83      0.84      1296
#        weighted avg       0.90      0.90      0.90      1296

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

class_names=['Day', 'Night-Not_Separated', 'Night-Separated', 'No_Sky']
def show_confusion_matrix(confusion_matrix):
  hmap = sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Blues")
  hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
  hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=30, ha='right')
  plt.ylabel('True Class')
  plt.xlabel('Predicted Class');

cm = confusion_matrix(real_targets, real_prediction)
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names)
show_confusion_matrix(df_cm)

# %%
reden = -1
for item in X_val:
  reden = reden +1
  if real_targets[reden] != real_prediction[reden]:
    print(validation_x[reden], real_targets[reden], real_prediction[reden])
# Out:
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_230.jpg 2 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_94.jpg 2 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_319.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_367.jpg 2 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_335.jpg 2 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_5.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_236.jpg 2 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_215.jpg 2 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_371.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_348.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_254.jpg 2 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_41.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_160.jpg 2 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_125.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_233.jpg 2 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_171.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_172.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_112.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_142.jpg 2 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_411.jpg 2 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_343.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_322.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_66.jpg 2 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_356.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_331.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_241.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_490.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_557.jpg 2 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_605.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_531.jpg 2 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_599.jpg 2 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_630.jpg 2 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_641.jpg 2 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Separated/night_separated_590.jpg 2 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_244.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1367.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_2911.jpg 3 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_2800.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_2509.jpg 3 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_3554.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_3380.jpg 3 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_3191.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_3071.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_3289.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_3730.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_3823.jpg 3 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_3658.jpg 3 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1920.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_2209.jpg 3 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1939.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_2469.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_2045.jpg 3 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_2558.jpg 3 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_714.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_707.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_855.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1055.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_978.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_675.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1637.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1463.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1490.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1661.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1140.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1405.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1675.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1195.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1507.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1487.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1584.jpg 3 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1715.jpg 3 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_584.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_501.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_240.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_198.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_312.jpg 3 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/No_Sky/no_sky_1096.jpg 3 1
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_2728.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_2798.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_2551.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_2738.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_3039.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_3075.jpg 0 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_3003.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_3180.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_2976.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_3085.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_2930.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/no_sky_3169.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_1278.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_1471.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_1200.jpg 0 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_1530.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_1122.jpg 0 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_2164.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_2169.jpg 0 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_1892.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_1804.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_1915.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_2435.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_680.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_567.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_885.jpg 0 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_1546.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Day/day_38.jpg 0 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_2.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_1.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_404.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_323.jpg 1 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_205.jpg 1 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_345.jpg 1 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_181.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_470.jpg 1 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_40.jpg 1 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_501.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_642.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_121.jpg 1 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_169.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_636.jpg 1 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_204.jpg 1 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_667.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_452.jpg 1 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_187.jpg 1 0
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_95.jpg 1 3
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_532.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_783.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_721.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_874.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_726.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_825.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_807.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_798.jpg 1 2
# /content/drive/MyDrive/edited_Jasmina_labeled_resized_224x224/Night-Not_Separated/night_not_separated_688.jpg 1 3

# %% [markdown]
# # Example :
#    Provide several examples of predictions along with softmax score probability

# %% [markdown]
# # Benchmark

# %%
def get_prediction(image):
    image = np.expand_dims(image, axis=0)
    
    # istreniraniot model go koristime za prepoznavanje
    prediction = model.predict(image)
    # prepoznaenata klasa ni e indeksot od najgolemata vrednost vo izlezot (prediction), najgolemata verojatnost
    predicted_class = np.argmax(prediction)
    return target_names[predicted_class]

# %%
import urllib.request
import cv2

def url_to_image(url):
  resp = urllib.request.urlopen(url)
  image = np.asarray(bytearray(resp.read()), dtype="uint8")
  image = cv2.imdecode(image, cv2.IMREAD_COLOR)
  image_ = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  # PREPROCESS YOUR INPUT
  image_preprocessed = preprocess_input(cv2.resize(image, dsize = (224,224)))
  return image_preprocessed, image_

def predict_url(url):
  image_resized, image = url_to_image(url)
  predicted_class = get_prediction(image_resized)
  plt.imshow(image)
  plt.title("Предвидено : " + predicted_class)

# %%
predict_url("https://d17fnq9dkz9hgj.cloudfront.net/uploads/2018/04/Pomeranian_02.jpg")

# %%
predict_url("https://images.unsplash.com/photo-1463947628408-f8581a2f4aca?ixlib=rb-1.2.1&ixid=MXwxMjA3fDB8MHxleHBsb3JlLWZlZWR8Mnx8fGVufDB8fHw%3D&auto=format&fit=crop&w=500&q=60")

# %%
predict_url("https://images.unsplash.com/photo-1468276311594-df7cb65d8df6?ixlib=rb-1.2.1&ixid=MXwxMjA3fDB8MHxleHBsb3JlLWZlZWR8OXx8fGVufDB8fHw%3D&auto=format&fit=crop&w=500&q=60")

# %%
predict_url("https://scontent.fskp2-1.fna.fbcdn.net/v/t31.0-8/p960x960/10945111_1532150797037312_5930509058927773875_o.jpg?_nc_cat=111&ccb=3&_nc_sid=e3f864&_nc_ohc=FfcA0O6r2LAAX_L3gIe&_nc_ht=scontent.fskp2-1.fna&tp=6&oh=6b433ef1607a363f79d6bff5242a6112&oe=604F3D3A")

# %%
predict_url("data:image/jpeg;base64,...")

# %%
predict_url("https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTal6nSKLhNL8KkKlHf4uv_PbknncdEKST0qQ&usqp=CAU")

# %%
predict_url("https://cdn-prod.medicalnewstoday.com/content/images/articles/326/326378/a-woman-out-for-a-hike-wondering-if-black-people-can-get-sunburned.jpg")

# %%
predict_url("https://www.nationalgeographic.com/content/dam/news/photos/000/774/77403.jpg")

# %%
predict_url("https://www.markmallett.com/blog/wp-content/uploads/2015/03/people-walking-in-dark.jpg")

# %% [markdown]
# # Summary about your results
