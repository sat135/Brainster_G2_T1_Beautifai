# %% [markdown]
# # Beautif.ai classification
#
# The goal of your project is to create a robust classifier, to collect data and prepare custom dataset.
# You will build a model that will recognize 4 types of natural events in nature/indoor/outdoor:
#
# * Daylight sky
#   * <img src = "https://ak.picdn.net/shutterstock/videos/7077064/thumb/1.jpg" width = "50%" height="50%">
# * Sky at night
#   * <img src="https://i.pinimg.com/originals/ec/98/dd/ec98dd97904e60661b1d545a88006e6a.jpg" width="50%" height="50%"/>
#
# * Picture doesn't contain sky (no matter it's day or night)
#   * <img src= "https://www.hotelsolun.com/application/files/5515/6285/1004/1X9A8812.jpg" width="50%" height="50%"/>
#
#
# This project consists of the following activities :
#
#
# 1. Phase 1 : Dataset
#     * Team Planning
#     * Full git project Integration
#     * General Project Research
#     * Dataset Collection
#     * Dataset Preparation
# 2. Phase 2 : Training
#     * Research about neural networks
#     * Compose neural network architectures
#     * Ping Pong phase with Dataset labelers
#     * Generate syntethic data if needed
#     * Fine tunning of your model
# 3. Phase 3 : Deployment
#     * Analysis and benchmark Precision/Recall
#     * Model Deploy (Git)
#     * Write git Readme.md file
#     * Receive Feedback from PM

# %% [markdown]
# # Load Data

# %%
import os
from google.colab import drive
from PIL import Image
import shutil
import random
import cv2
from keras.applications.xception import preprocess_input as X_pre
from keras.applications.resnet50 import preprocess_input as Res_pre
import numpy as np

from sklearn.datasets import load_files  
import numpy as np
from keras.utils import np_utils
import cv2

import keras
from keras.preprocessing.image import load_img, img_to_array
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.applications.xception import Xception
from keras.applications.densenet import DenseNet169
from keras.applications.resnet import ResNet50
from keras.models import Model, Sequential, load_model
from keras.layers import Dense, Activation, Conv2D, Flatten, MaxPooling2D, AveragePooling2D, Dropout, GlobalAveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ModelCheckpoint

import matplotlib.pyplot as plt

plt.style.use( "ggplot" )

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def split_test_valid( split_ratio, set_path, random_seed = 1, print_ratio = False, include_path = True ) :

    """
    This functions lists through a directory containing different sets in sorted subdirectories and returns test_x, valid_x, test_labels, valid_labels ( or x and y ) for further use.
    The arguments that need to be provided:
        split_ratio: is the ratio for the data set to be split along. Acceptable input is a float between 0 and 1 i.e. the percentage needed for further use; 
        set_path: is the path to the main directory where the subdirectories are located.
    Optional arguments:
         random_seed: is self-explanatory;
         print_ratio: prints the int ratio of the split.
         include_path: whether or not to include the full path in the train and test sets.
            If True returns: '/content/drive/MyDrive/Directory/Subdirectiory/Image.jpg';
            If False returns: 'Image.jpg'.
    """

    random.seed( random_seed )
    
    total = 0

    test_x = []
    valid_x = []
    test_labels = []
    valid_labels = []

    default_location = os.getcwd()

    if set_path[ -1 ] == "/" :
        set_path = set_path[0:-1]

    os.chdir( set_path )
    list_dir = os.listdir( set_path )

    for folder in list_dir :
        os.chdir( f'{ set_path}/{ folder }' )
        how_many =  len( os.listdir() )
        total += how_many

        test_set = int( round( how_many * ( 1 - split_ratio ), 0 ) )
        valid_set = int( round( how_many * split_ratio, 0 ) )

        nums = [ x for x in range( 1, how_many ) ]
        random_nums = random.sample( nums, valid_set )

        # The split itself :
        for ind, item in enumerate( os.listdir() ):

            if ind in random_nums :
                if include_path == True :
                    valid_x.append( f"{set_path}/{folder}/{item}" )
                elif include_path == False :
                    valid_x.append( item )

                valid_labels.append( folder )

            if ind not in random_nums :

                if include_path == True :
                    test_x.append( f"{set_path}/{folder}/{item}" )
                elif include_path == False :
                    test_x.append( item )

                test_labels.append( folder )

        if print_ratio == True :

            print( f"Set: { folder } - { how_many } items" )
            print( f"Train: { test_set }" )
            print( f"Validation: { valid_set }" )
            print( f"Total: { test_set + valid_set }" )
            print( "---------" )
        elif print_ratio == False :
            pass

    os.chdir( default_location )
    
    if print_ratio == True :
        test_set = int( round( total * ( 1 - split_ratio ), 0 ) )
        valid_set = int( round( total * split_ratio, 0 ) )

        print( "---------" ) 
        print( f"United set: { total } items" )
        print( f"Train: { test_set }" )
        print( f"Validation: { valid_set }" )
        print( f"Total: { test_set + valid_set }" )
        print( "---------" )
    elif print_ratio == False :
            pass

    return test_x, valid_x, test_labels, valid_labels

# %%
set_path = "/content/drive/MyDrive/labeled_resized_224x224"
split_ratio = 0.15

train_x, validation_x, train_labels, validation_labels  = split_test_valid( split_ratio, set_path, random_seed = 42, print_ratio = True )
# Out:
# Set: No_Sky - 3826 items
# Train: 3252
# Validation: 574
# Total: 3826
# ---------
# Set: Night-Not_Separated - 884 items
# Train: 751
# Validation: 133
# Total: 884
# ---------
# Set: Day - 3273 items
# Train: 2782
# Validation: 491
# Total: 3273
# ---------
# Set: Night-Separated - 657 items
# Train: 558
# Validation: 99
# Total: 657
# ---------
# ---------
# United set: 8640 items
# Train: 7344
# Validation: 1296
# Total: 8640
# ---------

# %%
train_labels = np.array(train_labels)
validation_labels = np.array(validation_labels)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
le.fit(train_labels)
# Out:
# LabelEncoder()

# %%
train_targets = le.transform(train_labels)
val_targets = le.transform(validation_labels)

# %%
from tensorflow.keras.utils import to_categorical

# %%
train_targets = np_utils.to_categorical(train_targets,num_classes=4)
val_targets = np_utils.to_categorical(val_targets,num_classes=4)

# %% [markdown]
# # Visualize Data Distribution

# %% [markdown]
# # Image Preprocessing

# %%
def load_image( path ) :
  # READ AND PREPROCESS IMAGE HERE
  #cv2.imread
  image = cv2.imread( path ).astype( np.float32 )
  image_resized = Res_pre( image )
  return image_resized

def load_dataset( files ) :
  vector = []
  brojcanik = 0
  for file in files:
    brojcanik = brojcanik + 1
    vector.append( load_image( file ) )
    if brojcanik%100 == 0:
      print(f"procesirani se vkupno {brojcanik} sliki")
  return np.array( vector )


X_train = load_dataset( train_x )
X_val = load_dataset( validation_x )
# Out:
# procesirani se vkupno 100 sliki
# procesirani se vkupno 200 sliki
# procesirani se vkupno 300 sliki
# procesirani se vkupno 400 sliki
# procesirani se vkupno 500 sliki
# procesirani se vkupno 600 sliki
# procesirani se vkupno 700 sliki
# procesirani se vkupno 800 sliki
# procesirani se vkupno 900 sliki
# procesirani se vkupno 1000 sliki
# procesirani se vkupno 1100 sliki
# procesirani se vkupno 1200 sliki
# procesirani se vkupno 1300 sliki
# procesirani se vkupno 1400 sliki
# procesirani se vkupno 1500 sliki
# procesirani se vkupno 1600 sliki
# procesirani se vkupno 1700 sliki
# procesirani se vkupno 1800 sliki
# procesirani se vkupno 1900 sliki
# procesirani se vkupno 2000 sliki
# procesirani se vkupno 2100 sliki
# procesirani se vkupno 2200 sliki
# procesirani se vkupno 2300 sliki
# procesirani se vkupno 2400 sliki
# procesirani se vkupno 2500 sliki
# procesirani se vkupno 2600 sliki
# procesirani se vkupno 2700 sliki
# procesirani se vkupno 2800 sliki
# procesirani se vkupno 2900 sliki
# procesirani se vkupno 3000 sliki
# procesirani se vkupno 3100 sliki
# procesirani se vkupno 3200 sliki
# procesirani se vkupno 3300 sliki
# procesirani se vkupno 3400 sliki
# procesirani se vkupno 3500 sliki
# procesirani se vkupno 3600 sliki
# procesirani se vkupno 3700 sliki
# procesirani se vkupno 3800 sliki
# procesirani se vkupno 3900 sliki
# procesirani se vkupno 4000 sliki
# procesirani se vkupno 4100 sliki
# procesirani se vkupno 4200 sliki
# procesirani se vkupno 4300 sliki
# procesirani se vkupno 4400 sliki
# procesirani se vkupno 4500 sliki
# procesirani se vkupno 4600 sliki
# procesirani se vkupno 4700 sliki
# procesirani se vkupno 4800 sliki
# procesirani se vkupno 4900 sliki
# procesirani se vkupno 5000 sliki
# procesirani se vkupno 5100 sliki
# procesirani se vkupno 5200 sliki
# procesirani se vkupno 5300 sliki
# procesirani se vkupno 5400 sliki
# procesirani se vkupno 5500 sliki
# procesirani se vkupno 5600 sliki
# procesirani se vkupno 5700 sliki
# procesirani se vkupno 5800 sliki
# procesirani se vkupno 5900 sliki
# procesirani se vkupno 6000 sliki
# procesirani se vkupno 6100 sliki
# procesirani se vkupno 6200 sliki
# procesirani se vkupno 6300 sliki
# procesirani se vkupno 6400 sliki
# procesirani se vkupno 6500 sliki
# procesirani se vkupno 6600 sliki
# procesirani se vkupno 6700 sliki
# procesirani se vkupno 6800 sliki
# procesirani se vkupno 6900 sliki
# procesirani se vkupno 7000 sliki
# procesirani se vkupno 7100 sliki
# procesirani se vkupno 7200 sliki
# procesirani se vkupno 7300 sliki
# procesirani se vkupno 100 sliki
# procesirani se vkupno 200 sliki
# procesirani se vkupno 300 sliki
# procesirani se vkupno 400 sliki
# procesirani se vkupno 500 sliki
# procesirani se vkupno 600 sliki
# procesirani se vkupno 700 sliki
# procesirani se vkupno 800 sliki
# procesirani se vkupno 900 sliki
# procesirani se vkupno 1000 sliki
# procesirani se vkupno 1100 sliki
# procesirani se vkupno 1200 sliki

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20,20))

for i in range( 5 * 4 ) :
    # dodavanje na podgrafik
    ax1 = fig.add_subplot( 5, 4, ( i + 1 ) )
    # crtanje na podgrafikot
    ax1.imshow( X_train[ i ] )
    #  dodavanje na tekst na podgrafikot
    title = "Class: " + train_labels[ i ]
    plt.title( title )

# snimanje na grafikot
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20,20))

for i in range( 5 * 4 ) :
    # dodavanje na podgrafik
    ax1 = fig.add_subplot( 5, 4, ( i + 1 ) )
    # crtanje na podgrafikot
    ax1.imshow( X_val[ i ] )
    #  dodavanje na tekst na podgrafikot
    title = "Class: " + validation_labels[ i ]
    plt.title( title )

# snimanje na grafikot
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from keras.applications.resnet import ResNet101

# %% [markdown]
# # Define Model Architecture

# %%
model = ResNet50(include_top=False, input_shape = (224,224,3), weights='imagenet')
for layer in model.layers:
  layer.trainable=False
flat = Flatten()(model.output)
hidden = Dense(1024, activation='relu')(flat)
outputs = Dense(4, activation='softmax')(hidden)
model = Model(inputs = model.inputs, outputs = outputs)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 100352)       0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         102761472   flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4)            4100        dense[0][0]
# ==================================================================================================
# Total params: 126,353,284
# Trainable params: 102,765,572
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %% [markdown]
# # Define Loss Function, Optimizator

# %%
optimzer = keras.optimizers.Adam(lr = 0.00001)
model.compile( loss = 'categorical_crossentropy', optimizer = optimzer, metrics = [ 'accuracy' ] )

# %% [markdown]
# # Define Augmentator

# %%
checkpoint = ModelCheckpoint(     
                                'best_model_JLN.pt', monitor = 'val_accuracy',
                                verbose = 1, save_best_only = True, mode = 'max'
                               )

model.fit(
                    X_train,
                    train_targets,
                    validation_data = ( X_val, val_targets ),
                    epochs = 100,
                    callbacks = [ checkpoint ], 
                    batch_size = 30
                        )
# Out:
# Epoch 1/100
# 245/245 [==============================] - 42s 133ms/step - loss: 0.8687 - accuracy: 0.7501 - val_loss: 0.4107 - val_accuracy: 0.8797
#
# Epoch 00001: val_accuracy improved from -inf to 0.87972, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 2/100
# 245/245 [==============================] - 32s 129ms/step - loss: 0.0454 - accuracy: 0.9854 - val_loss: 0.4230 - val_accuracy: 0.8890
#
# Epoch 00002: val_accuracy improved from 0.87972 to 0.88897, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 3/100
# 245/245 [==============================] - 32s 130ms/step - loss: 0.0158 - accuracy: 0.9980 - val_loss: 0.4285 - val_accuracy: 0.8913
#
# Epoch 00003: val_accuracy improved from 0.88897 to 0.89129, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 4/100
# 245/245 [==============================] - 33s 135ms/step - loss: 0.0096 - accuracy: 0.9983 - val_loss: 0.4479 - val_accuracy: 0.8944
#
# Epoch 00004: val_accuracy improved from 0.89129 to 0.89437, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 5/100
# 245/245 [==============================] - 33s 133ms/step - loss: 0.0124 - accuracy: 0.9984 - val_loss: 0.4540 - val_accuracy: 0.8913
#
# Epoch 00005: val_accuracy did not improve from 0.89437
# Epoch 6/100
# 245/245 [==============================] - 33s 134ms/step - loss: 0.0125 - accuracy: 0.9991 - val_loss: 0.4814 - val_accuracy: 0.8874
#
# Epoch 00006: val_accuracy did not improve from 0.89437
# Epoch 7/100
# 245/245 [==============================] - 32s 131ms/step - loss: 0.0170 - accuracy: 0.9989 - val_loss: 0.4614 - val_accuracy: 0.8921
#
# Epoch 00007: val_accuracy did not improve from 0.89437
# Epoch 8/100
# 245/245 [==============================] - 33s 133ms/step - loss: 0.0131 - accuracy: 0.9975 - val_loss: 0.4711 - val_accuracy: 0.8882
#
# Epoch 00008: val_accuracy did not improve from 0.89437
# Epoch 9/100
# 245/245 [==============================] - 32s 132ms/step - loss: 0.0082 - accuracy: 0.9994 - val_loss: 0.4705 - val_accuracy: 0.8890
#
# Epoch 00009: val_accuracy did not improve from 0.89437
# Epoch 10/100
# 245/245 [==============================] - 32s 131ms/step - loss: 0.0111 - accuracy: 0.9990 - val_loss: 0.4709 - val_accuracy: 0.8882
#
# Epoch 00010: val_accuracy did not improve from 0.89437
# Epoch 11/100
# 245/245 [==============================] - 32s 132ms/step - loss: 0.0080 - accuracy: 0.9991 - val_loss: 0.5008 - val_accuracy: 0.8905
#
# Epoch 00011: val_accuracy did not improve from 0.89437
# Epoch 12/100
# 245/245 [==============================] - 32s 132ms/step - loss: 0.0107 - accuracy: 0.9992 - val_loss: 0.5394 - val_accuracy: 0.8913
#
# Epoch 00012: val_accuracy did not improve from 0.89437
# Epoch 13/100
# 245/245 [==============================] - 32s 132ms/step - loss: 0.0180 - accuracy: 0.9982 - val_loss: 0.5452 - val_accuracy: 0.8805
#
# Epoch 00013: val_accuracy did not improve from 0.89437
# Epoch 14/100
# 245/245 [==============================] - 32s 132ms/step - loss: 0.0218 - accuracy: 0.9970 - val_loss: 0.5178 - val_accuracy: 0.8882
#
# Epoch 00014: val_accuracy did not improve from 0.89437
# Epoch 15/100
# 245/245 [==============================] - 32s 132ms/step - loss: 0.0090 - accuracy: 0.9993 - val_loss: 0.5555 - val_accuracy: 0.8820
#
# Epoch 00015: val_accuracy did not improve from 0.89437
# Epoch 16/100
# 245/245 [==============================] - 32s 132ms/step - loss: 0.0308 - accuracy: 0.9972 - val_loss: 0.5343 - val_accuracy: 0.8921
#
# Epoch 00016: val_accuracy did not improve from 0.89437
# Epoch 17/100
# 245/245 [==============================] - 32s 131ms/step - loss: 0.0053 - accuracy: 0.9994 - val_loss: 0.5991 - val_accuracy: 0.8759
#
# Epoch 00017: val_accuracy did not improve from 0.89437
# Epoch 18/100
# 245/245 [==============================] - 32s 131ms/step - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.6622 - val_accuracy: 0.8751
#
# Epoch 00018: val_accuracy did not improve from 0.89437
# Epoch 19/100
# 245/245 [==============================] - 32s 131ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.5674 - val_accuracy: 0.8859
#
# Epoch 00019: val_accuracy did not improve from 0.89437
# Epoch 20/100
# 245/245 [==============================] - 32s 131ms/step - loss: 0.0047 - accuracy: 0.9998 - val_loss: 0.5416 - val_accuracy: 0.8874
#
# Epoch 00020: val_accuracy did not improve from 0.89437
# Epoch 21/100
# 245/245 [==============================] - 32s 131ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 0.5635 - val_accuracy: 0.8897
#
# Epoch 00021: val_accuracy did not improve from 0.89437
# Epoch 22/100
# 245/245 [==============================] - 32s 131ms/step - loss: 0.0058 - accuracy: 0.9996 - val_loss: 0.5704 - val_accuracy: 0.8805
#
# Epoch 00022: val_accuracy did not improve from 0.89437
# Epoch 23/100
# 245/245 [==============================] - 32s 131ms/step - loss: 0.0078 - accuracy: 0.9996 - val_loss: 0.5818 - val_accuracy: 0.8766
#
# Epoch 00023: val_accuracy did not improve from 0.89437
# Epoch 24/100
# 245/245 [==============================] - 32s 131ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.5747 - val_accuracy: 0.8867
#
# Epoch 00024: val_accuracy did not improve from 0.89437
# Epoch 25/100
# 245/245 [==============================] - 32s 131ms/step - loss: 0.0162 - accuracy: 0.9962 - val_loss: 0.9103 - val_accuracy: 0.8682
#
# Epoch 00025: val_accuracy did not improve from 0.89437
# Epoch 26/100
# 245/245 [==============================] - 32s 131ms/step - loss: 0.1190 - accuracy: 0.9703 - val_loss: 0.6406 - val_accuracy: 0.8836
#
# Epoch 00026: val_accuracy did not improve from 0.89437
# Epoch 27/100
# 245/245 [==============================] - 32s 131ms/step - loss: 0.0113 - accuracy: 0.9972 - val_loss: 0.6392 - val_accuracy: 0.8897
#
# Epoch 00027: val_accuracy did not improve from 0.89437
# Epoch 28/100
# 245/245 [==============================] - 32s 131ms/step - loss: 7.3041e-04 - accuracy: 0.9999 - val_loss: 0.6246 - val_accuracy: 0.8867
#
# Epoch 00028: val_accuracy did not improve from 0.89437
# Epoch 29/100
# 245/245 [==============================] - 32s 131ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.6501 - val_accuracy: 0.8890
#
# Epoch 00029: val_accuracy did not improve from 0.89437
# Epoch 30/100
# 245/245 [==============================] - 32s 131ms/step - loss: 1.3881e-04 - accuracy: 1.0000 - val_loss: 0.6988 - val_accuracy: 0.8882
#
# Epoch 00030: val_accuracy did not improve from 0.89437
# Epoch 31/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.4973e-04 - accuracy: 1.0000 - val_loss: 0.6532 - val_accuracy: 0.8905
#
# Epoch 00031: val_accuracy did not improve from 0.89437
# Epoch 32/100
# 245/245 [==============================] - 32s 132ms/step - loss: 6.2496e-05 - accuracy: 1.0000 - val_loss: 0.6601 - val_accuracy: 0.8913
#
# Epoch 00032: val_accuracy did not improve from 0.89437
# Epoch 33/100
# 245/245 [==============================] - 32s 132ms/step - loss: 5.7429e-05 - accuracy: 1.0000 - val_loss: 0.6647 - val_accuracy: 0.8913
#
# Epoch 00033: val_accuracy did not improve from 0.89437
# Epoch 34/100
# 245/245 [==============================] - 32s 132ms/step - loss: 5.0400e-05 - accuracy: 1.0000 - val_loss: 0.6683 - val_accuracy: 0.8913
#
# Epoch 00034: val_accuracy did not improve from 0.89437
# Epoch 35/100
# 245/245 [==============================] - 32s 133ms/step - loss: 4.4871e-05 - accuracy: 1.0000 - val_loss: 0.6721 - val_accuracy: 0.8921
#
# Epoch 00035: val_accuracy did not improve from 0.89437
# Epoch 36/100
# 245/245 [==============================] - 32s 133ms/step - loss: 3.7065e-05 - accuracy: 1.0000 - val_loss: 0.6758 - val_accuracy: 0.8913
#
# Epoch 00036: val_accuracy did not improve from 0.89437
# Epoch 37/100
# 245/245 [==============================] - 32s 132ms/step - loss: 3.1387e-05 - accuracy: 1.0000 - val_loss: 0.6796 - val_accuracy: 0.8921
#
# Epoch 00037: val_accuracy did not improve from 0.89437
# Epoch 38/100
# 245/245 [==============================] - 32s 132ms/step - loss: 2.9219e-05 - accuracy: 1.0000 - val_loss: 0.6825 - val_accuracy: 0.8928
#
# Epoch 00038: val_accuracy did not improve from 0.89437
# Epoch 39/100
# 245/245 [==============================] - 32s 132ms/step - loss: 2.5723e-05 - accuracy: 1.0000 - val_loss: 0.6867 - val_accuracy: 0.8928
#
# Epoch 00039: val_accuracy did not improve from 0.89437
# Epoch 40/100
# 245/245 [==============================] - 32s 132ms/step - loss: 2.2083e-05 - accuracy: 1.0000 - val_loss: 0.6904 - val_accuracy: 0.8928
#
# Epoch 00040: val_accuracy did not improve from 0.89437
# Epoch 41/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.9921e-05 - accuracy: 1.0000 - val_loss: 0.6933 - val_accuracy: 0.8928
#
# Epoch 00041: val_accuracy did not improve from 0.89437
# Epoch 42/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.7520e-05 - accuracy: 1.0000 - val_loss: 0.6973 - val_accuracy: 0.8928
#
# Epoch 00042: val_accuracy did not improve from 0.89437
# Epoch 43/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.5810e-05 - accuracy: 1.0000 - val_loss: 0.7014 - val_accuracy: 0.8928
#
# Epoch 00043: val_accuracy did not improve from 0.89437
# Epoch 44/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.3787e-05 - accuracy: 1.0000 - val_loss: 0.7053 - val_accuracy: 0.8928
#
# Epoch 00044: val_accuracy did not improve from 0.89437
# Epoch 45/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.2349e-05 - accuracy: 1.0000 - val_loss: 0.7091 - val_accuracy: 0.8936
#
# Epoch 00045: val_accuracy did not improve from 0.89437
# Epoch 46/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.0982e-05 - accuracy: 1.0000 - val_loss: 0.7123 - val_accuracy: 0.8944
#
# Epoch 00046: val_accuracy did not improve from 0.89437
# Epoch 47/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.0056e-05 - accuracy: 1.0000 - val_loss: 0.7162 - val_accuracy: 0.8936
#
# Epoch 00047: val_accuracy did not improve from 0.89437
# Epoch 48/100
# 245/245 [==============================] - 32s 132ms/step - loss: 9.3586e-06 - accuracy: 1.0000 - val_loss: 0.7193 - val_accuracy: 0.8936
#
# Epoch 00048: val_accuracy did not improve from 0.89437
# Epoch 49/100
# 245/245 [==============================] - 32s 132ms/step - loss: 8.1504e-06 - accuracy: 1.0000 - val_loss: 0.7229 - val_accuracy: 0.8936
#
# Epoch 00049: val_accuracy did not improve from 0.89437
# Epoch 50/100
# 245/245 [==============================] - 32s 132ms/step - loss: 6.8776e-06 - accuracy: 1.0000 - val_loss: 0.7271 - val_accuracy: 0.8928
#
# Epoch 00050: val_accuracy did not improve from 0.89437
# Epoch 51/100
# 245/245 [==============================] - 32s 132ms/step - loss: 6.1807e-06 - accuracy: 1.0000 - val_loss: 0.7302 - val_accuracy: 0.8921
#
# Epoch 00051: val_accuracy did not improve from 0.89437
# Epoch 52/100
# 245/245 [==============================] - 32s 132ms/step - loss: 5.5317e-06 - accuracy: 1.0000 - val_loss: 0.7344 - val_accuracy: 0.8921
#
# Epoch 00052: val_accuracy did not improve from 0.89437
# Epoch 53/100
# 245/245 [==============================] - 32s 131ms/step - loss: 5.0175e-06 - accuracy: 1.0000 - val_loss: 0.7381 - val_accuracy: 0.8928
#
# Epoch 00053: val_accuracy did not improve from 0.89437
# Epoch 54/100
# 245/245 [==============================] - 32s 132ms/step - loss: 4.4904e-06 - accuracy: 1.0000 - val_loss: 0.7421 - val_accuracy: 0.8921
#
# Epoch 00054: val_accuracy did not improve from 0.89437
# Epoch 55/100
# 245/245 [==============================] - 32s 131ms/step - loss: 4.1454e-06 - accuracy: 1.0000 - val_loss: 0.7466 - val_accuracy: 0.8928
#
# Epoch 00055: val_accuracy did not improve from 0.89437
# Epoch 56/100
# 245/245 [==============================] - 32s 132ms/step - loss: 3.5984e-06 - accuracy: 1.0000 - val_loss: 0.7502 - val_accuracy: 0.8928
#
# Epoch 00056: val_accuracy did not improve from 0.89437
# Epoch 57/100
# 245/245 [==============================] - 32s 132ms/step - loss: 3.1033e-06 - accuracy: 1.0000 - val_loss: 0.7539 - val_accuracy: 0.8936
#
# Epoch 00057: val_accuracy did not improve from 0.89437
# Epoch 58/100
# 245/245 [==============================] - 32s 132ms/step - loss: 2.7780e-06 - accuracy: 1.0000 - val_loss: 0.7579 - val_accuracy: 0.8936
#
# Epoch 00058: val_accuracy did not improve from 0.89437
# Epoch 59/100
# 245/245 [==============================] - 32s 132ms/step - loss: 2.5751e-06 - accuracy: 1.0000 - val_loss: 0.7614 - val_accuracy: 0.8936
#
# Epoch 00059: val_accuracy did not improve from 0.89437
# Epoch 60/100
# 245/245 [==============================] - 32s 132ms/step - loss: 2.3296e-06 - accuracy: 1.0000 - val_loss: 0.7659 - val_accuracy: 0.8928
#
# Epoch 00060: val_accuracy did not improve from 0.89437
# Epoch 61/100
# 245/245 [==============================] - 32s 131ms/step - loss: 1.9682e-06 - accuracy: 1.0000 - val_loss: 0.7699 - val_accuracy: 0.8928
#
# Epoch 00061: val_accuracy did not improve from 0.89437
# Epoch 62/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.7320e-06 - accuracy: 1.0000 - val_loss: 0.7741 - val_accuracy: 0.8928
#
# Epoch 00062: val_accuracy did not improve from 0.89437
# Epoch 63/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.5732e-06 - accuracy: 1.0000 - val_loss: 0.7782 - val_accuracy: 0.8928
#
# Epoch 00063: val_accuracy did not improve from 0.89437
# Epoch 64/100
# 245/245 [==============================] - 32s 131ms/step - loss: 1.4423e-06 - accuracy: 1.0000 - val_loss: 0.7815 - val_accuracy: 0.8936
#
# Epoch 00064: val_accuracy did not improve from 0.89437
# Epoch 65/100
# 245/245 [==============================] - 32s 131ms/step - loss: 1.2059e-06 - accuracy: 1.0000 - val_loss: 0.7852 - val_accuracy: 0.8944
#
# Epoch 00065: val_accuracy did not improve from 0.89437
# Epoch 66/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.0835e-06 - accuracy: 1.0000 - val_loss: 0.7897 - val_accuracy: 0.8936
#
# Epoch 00066: val_accuracy did not improve from 0.89437
# Epoch 67/100
# 245/245 [==============================] - 32s 131ms/step - loss: 9.8918e-07 - accuracy: 1.0000 - val_loss: 0.7930 - val_accuracy: 0.8936
#
# Epoch 00067: val_accuracy did not improve from 0.89437
# Epoch 68/100
# 245/245 [==============================] - 32s 132ms/step - loss: 8.8934e-07 - accuracy: 1.0000 - val_loss: 0.7970 - val_accuracy: 0.8944
#
# Epoch 00068: val_accuracy did not improve from 0.89437
# Epoch 69/100
# 245/245 [==============================] - 32s 132ms/step - loss: 7.9985e-07 - accuracy: 1.0000 - val_loss: 0.8023 - val_accuracy: 0.8959
#
# Epoch 00069: val_accuracy improved from 0.89437 to 0.89591, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 70/100
# 245/245 [==============================] - 33s 134ms/step - loss: 6.8665e-07 - accuracy: 1.0000 - val_loss: 0.8056 - val_accuracy: 0.8959
#
# Epoch 00070: val_accuracy did not improve from 0.89591
# Epoch 71/100
# 245/245 [==============================] - 32s 132ms/step - loss: 6.2945e-07 - accuracy: 1.0000 - val_loss: 0.8094 - val_accuracy: 0.8951
#
# Epoch 00071: val_accuracy did not improve from 0.89591
# Epoch 72/100
# 245/245 [==============================] - 32s 131ms/step - loss: 5.3767e-07 - accuracy: 1.0000 - val_loss: 0.8124 - val_accuracy: 0.8951
#
# Epoch 00072: val_accuracy did not improve from 0.89591
# Epoch 73/100
# 245/245 [==============================] - 33s 133ms/step - loss: 4.7686e-07 - accuracy: 1.0000 - val_loss: 0.8168 - val_accuracy: 0.8959
#
# Epoch 00073: val_accuracy did not improve from 0.89591
# Epoch 74/100
# 245/245 [==============================] - 32s 132ms/step - loss: 4.3700e-07 - accuracy: 1.0000 - val_loss: 0.8215 - val_accuracy: 0.8951
#
# Epoch 00074: val_accuracy did not improve from 0.89591
# Epoch 75/100
# 245/245 [==============================] - 32s 132ms/step - loss: 3.8842e-07 - accuracy: 1.0000 - val_loss: 0.8252 - val_accuracy: 0.8959
#
# Epoch 00075: val_accuracy did not improve from 0.89591
# Epoch 76/100
# 245/245 [==============================] - 32s 132ms/step - loss: 3.5358e-07 - accuracy: 1.0000 - val_loss: 0.8290 - val_accuracy: 0.8959
#
# Epoch 00076: val_accuracy did not improve from 0.89591
# Epoch 77/100
# 245/245 [==============================] - 32s 132ms/step - loss: 3.0995e-07 - accuracy: 1.0000 - val_loss: 0.8322 - val_accuracy: 0.8944
#
# Epoch 00077: val_accuracy did not improve from 0.89591
# Epoch 78/100
# 245/245 [==============================] - 32s 132ms/step - loss: 2.6012e-07 - accuracy: 1.0000 - val_loss: 0.8358 - val_accuracy: 0.8959
#
# Epoch 00078: val_accuracy did not improve from 0.89591
# Epoch 79/100
# 245/245 [==============================] - 32s 132ms/step - loss: 2.3226e-07 - accuracy: 1.0000 - val_loss: 0.8399 - val_accuracy: 0.8959
#
# Epoch 00079: val_accuracy did not improve from 0.89591
# Epoch 80/100
# 245/245 [==============================] - 32s 132ms/step - loss: 2.1601e-07 - accuracy: 1.0000 - val_loss: 0.8433 - val_accuracy: 0.8959
#
# Epoch 00080: val_accuracy did not improve from 0.89591
# Epoch 81/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.8956e-07 - accuracy: 1.0000 - val_loss: 0.8484 - val_accuracy: 0.8959
#
# Epoch 00081: val_accuracy did not improve from 0.89591
# Epoch 82/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.7976e-07 - accuracy: 1.0000 - val_loss: 0.8514 - val_accuracy: 0.8959
#
# Epoch 00082: val_accuracy did not improve from 0.89591
# Epoch 83/100
# 245/245 [==============================] - 33s 133ms/step - loss: 1.6374e-07 - accuracy: 1.0000 - val_loss: 0.8542 - val_accuracy: 0.8959
#
# Epoch 00083: val_accuracy did not improve from 0.89591
# Epoch 84/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.4209e-07 - accuracy: 1.0000 - val_loss: 0.8577 - val_accuracy: 0.8967
#
# Epoch 00084: val_accuracy improved from 0.89591 to 0.89668, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 85/100
# 245/245 [==============================] - 33s 134ms/step - loss: 1.2391e-07 - accuracy: 1.0000 - val_loss: 0.8615 - val_accuracy: 0.8959
#
# Epoch 00085: val_accuracy did not improve from 0.89668
# Epoch 86/100
# 245/245 [==============================] - 33s 133ms/step - loss: 1.1419e-07 - accuracy: 1.0000 - val_loss: 0.8654 - val_accuracy: 0.8967
#
# Epoch 00086: val_accuracy did not improve from 0.89668
# Epoch 87/100
# 245/245 [==============================] - 32s 132ms/step - loss: 1.0372e-07 - accuracy: 1.0000 - val_loss: 0.8679 - val_accuracy: 0.8967
#
# Epoch 00087: val_accuracy did not improve from 0.89668
# Epoch 88/100
# 245/245 [==============================] - 32s 132ms/step - loss: 9.1243e-08 - accuracy: 1.0000 - val_loss: 0.8727 - val_accuracy: 0.8967
#
# Epoch 00088: val_accuracy did not improve from 0.89668
# Epoch 89/100
# 245/245 [==============================] - 32s 132ms/step - loss: 7.9891e-08 - accuracy: 1.0000 - val_loss: 0.8753 - val_accuracy: 0.8967
#
# Epoch 00089: val_accuracy did not improve from 0.89668
# Epoch 90/100
# 245/245 [==============================] - 32s 131ms/step - loss: 7.2273e-08 - accuracy: 1.0000 - val_loss: 0.8786 - val_accuracy: 0.8975
#
# Epoch 00090: val_accuracy improved from 0.89668 to 0.89746, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 91/100
# 245/245 [==============================] - 33s 134ms/step - loss: 6.7538e-08 - accuracy: 1.0000 - val_loss: 0.8816 - val_accuracy: 0.8967
#
# Epoch 00091: val_accuracy did not improve from 0.89746
# Epoch 92/100
# 245/245 [==============================] - 32s 132ms/step - loss: 6.1468e-08 - accuracy: 1.0000 - val_loss: 0.8846 - val_accuracy: 0.8975
#
# Epoch 00092: val_accuracy did not improve from 0.89746
# Epoch 93/100
# 245/245 [==============================] - 32s 131ms/step - loss: 5.3534e-08 - accuracy: 1.0000 - val_loss: 0.8884 - val_accuracy: 0.8975
#
# Epoch 00093: val_accuracy did not improve from 0.89746
# Epoch 94/100
# 245/245 [==============================] - 32s 133ms/step - loss: 4.8846e-08 - accuracy: 1.0000 - val_loss: 0.8898 - val_accuracy: 0.8967
#
# Epoch 00094: val_accuracy did not improve from 0.89746
# Epoch 95/100
# 245/245 [==============================] - 32s 132ms/step - loss: 4.4313e-08 - accuracy: 1.0000 - val_loss: 0.8940 - val_accuracy: 0.8975
#
# Epoch 00095: val_accuracy did not improve from 0.89746
# Epoch 96/100
# 245/245 [==============================] - 33s 133ms/step - loss: 4.2273e-08 - accuracy: 1.0000 - val_loss: 0.8964 - val_accuracy: 0.8982
#
# Epoch 00096: val_accuracy improved from 0.89746 to 0.89823, saving model to best_model_JLN.pt
# INFO:tensorflow:Assets written to: best_model_JLN.pt/assets
# Epoch 97/100
# 245/245 [==============================] - 33s 135ms/step - loss: 3.7663e-08 - accuracy: 1.0000 - val_loss: 0.9005 - val_accuracy: 0.8975
#
# Epoch 00097: val_accuracy did not improve from 0.89823
# Epoch 98/100
# 245/245 [==============================] - 32s 132ms/step - loss: 3.1621e-08 - accuracy: 1.0000 - val_loss: 0.9010 - val_accuracy: 0.8975
#
# Epoch 00098: val_accuracy did not improve from 0.89823
# Epoch 99/100
# 245/245 [==============================] - 32s 132ms/step - loss: 3.0965e-08 - accuracy: 1.0000 - val_loss: 0.9044 - val_accuracy: 0.8982
#
# Epoch 00099: val_accuracy did not improve from 0.89823
# Epoch 100/100
# 245/245 [==============================] - 33s 133ms/step - loss: 2.7227e-08 - accuracy: 1.0000 - val_loss: 0.9068 - val_accuracy: 0.8982
#
# Epoch 00100: val_accuracy did not improve from 0.89823

# %%
real_prediction = np.argmax(Y_pred, axis=1)
real_targets = np.argmax(val_targets, axis=1)

# %%
from sklearn.metrics import classification_report

Y_pred = model.predict(X_val)

target_names = ['Day', 'Night-Not_Separated', 'Night-Separated', 'No_Sky']
# print(classification_report(Y_test, Y_pred, target_names=target_names))
print(classification_report(real_targets, real_prediction, target_names=target_names))
# Out:
#                      precision    recall  f1-score   support
#
#                 Day       0.91      0.91      0.91       491
# Night-Not_Separated       0.81      0.81      0.81       133
#     Night-Separated       0.90      0.72      0.80        99
#              No_Sky       0.91      0.94      0.92       574
#
#            accuracy                           0.90      1297
#           macro avg       0.88      0.84      0.86      1297
#        weighted avg       0.90      0.90      0.90      1297

# %% [markdown]
# <!-- precision    recall  f1-score   support
#
#                 Day       0.91      0.91      0.91       491
# Night-Not_Separated       0.81      0.81      0.81       133
#     Night-Separated       0.90      0.71      0.79        99
#              No_Sky       0.91      0.94      0.92       574
#
#           micro avg       0.90      0.90      0.90      1297
#           macro avg       0.88      0.84      0.86      1297
#        weighted avg       0.90      0.90      0.90      1297
#         samples avg       0.90      0.90      0.90      1297 -->

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

class_names=['Day', 'Night-Not_Separated', 'Night-Separated', 'No_Sky']
def show_confusion_matrix(confusion_matrix):
  hmap = sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Blues")
  hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
  hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=30, ha='right')
  plt.ylabel('True Question')
  plt.xlabel('Predicted Question');

cm = confusion_matrix(real_targets, real_prediction)
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names)
show_confusion_matrix(df_cm)

# %% [markdown]
# # Example :
#    Provide several examples of predictions along with softmax score probability

# %% [markdown]
# # Benchmark

# %% [markdown]
# # Summary about your results
